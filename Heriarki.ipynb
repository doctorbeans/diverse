# %%
# !pip install pandas --upgrade
# Out:
# ...
#   Using cached pandas-1.1.4-cp38-cp38-macosx_10_9_x86_64.whl (10.1 MB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.0.1
#     Uninstalling pandas-1.0.1:
#       Successfully uninstalled pandas-1.0.1
# ...

# %%
import pandas as pd
import numpy as np

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
data = {'id':['A001','A002','A003','A004','A005'],'parent':[None,'A001','A002','A001','A003'], 'antall':[2,1,1,1,2]}
data
# Out:
# {'id': ['A001', 'A002', 'A003', 'A004', 'A005'],
#  'parent': [None, 'A001', 'A002', 'A001', 'A003'],
#  'antall': [2, 1, 1, 1, 2]}

# %%
df = pd.DataFrame(data=data)
df
# Out:
#      id parent  antall
# 0  A001   None       2
# 1  A002   A001       1
# 2  A003   A002       1
# 3  A004   A001       1
# 4  A005   A003       2

# %%
datoer = []
for row in df.iterrows():  
    print(dir(row[1]))
    if row[1].antall == 1:
        dato = 1
        datoer.append((row[1], dato))
    else:
        for j in range(row[1].antall):
            dato = 1+j
            datoer.append((row[1], dato))
datoer
# Out:
# ['T', '_AXIS_ALIASES', '_AXIS_IALIASES', '_AXIS_LEN', '_AXIS_NAMES', '_AXIS_NUMBERS', '_AXIS_ORDERS', '_AXIS_REVERSED', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__rd
# ...

# %%
df_fasit = pd.DataFrame(data={'id':[1.0,2.0,3.0,4.0], 'nivå_1':[1,1,1,1], 'nivå_2':[1,2,3,4], 'nivå_3':[1,2,3,4]})
df_fasit
# Out:
#     id  nivå_1  nivå_2  nivå_3
# 0  1.0       1       1       1
# 1  2.0       1       2       2
# 2  3.0       1       3       3
# 3  4.0       1       4       4

# %%
graf =  [['A059', 'A658'],
 ['A193', 'A917'],
 ['A503', 'A691'],
 ['A626', 'A865'],
 ['A834', 'A833'],
 ['A453', 'A697'],
 ['A213', 'A669'],
 ['A897', 'A021'],
 ['A057', 'A685'],
 ['A174', 'A725'],
 ['A249', 'A676'],
 ['A350', 'A630'],
 ['A536', 'A637'],
 ['A846', 'A800'],
 ['A107', 'A614'],
 ['A329', 'A633'],
 ['A395', 'A626'],
 ['A440', 'A690'],
 ['A514', 'A683'],
 ['A524', 'A798'],
 ['A900', 'A899'],
 ['A136', 'A719'],
 ['A167', 'A653'],
 ['A202', 'A662'],
 ['A233', 'A634'],
 ['A260', 'A664'],
 ['A302', 'A613'],
 ['A035', 'A034'],
 ['A281', 'A908'],
 ['A372', 'A642'],
 ['A042', 'A968'],
 ['A092', 'A912'],
 ['A544', 'A617'],
 ['A641', 'A865'],
 ['A658', 'A020'],
 ['A128', 'A623'],
 ['A801', 'A800'],
 ['A821', 'A811'],
 ['A881', 'A899'],
 ['A021', 'A677'],
 ['A147', 'A710'],
 ['A185', 'A916'],
 ['A398', 'A626'],
 ['A573', 'A724'],
 ['A723', 'A651'],
 ['A725', 'A020'],
 ['A964', 'A897'],
 ['A405', 'A625'],
 ['A561', 'A642'],
 ['A690', 'A722'],
 ['A706', 'A020'],
 ['A279', 'A909'],
 ['A647', 'A021'],
 ['A988', 'A986'],
 ['A079', 'A766'],
 ['A188', 'A916'],
 ['A777', 'A676'],
 ['A790', 'A031'],
 ['A844', 'A968'],
 ['A903', 'A024'],
 ['A032', 'A762'],
 ['A208', 'A669'],
 ['A223', 'A635'],
 ['A499', 'A689'],
 ['A975', 'A714'],
 ['A099', 'A695'],
 ['A448', 'A697'],
 ['A488', 'A865'],
 ['A549', 'A641'],
 ['A751', 'A624'],
 ['A209', 'A669'],
 ['A394', 'A800'],
 ['A625', 'A021'],
 ['A649', 'A624'],
 ['A705', 'A020'],
 ['A916', 'A024'],
 ['A154', 'A911'],
 ['A445', 'A800'],
 ['A575', 'A724'],
 ['A878', 'A800'],
 ['A072', 'A755'],
 ['A085', 'A766'],
 ['A176', 'A663'],
 ['A216', 'A668'],
 ['A261', 'A664'],
 ['A307', 'A716'],
 ['A704', 'A021'],
 ['A168', 'A653'],
 ['A239', 'A914'],
 ['A566', 'A798'],
 ['A807', 'A319'],
 ['A609', 'A050'],
 ['B002', 'A896'],
 ['A016', 'A655'],
 ['A198', 'A662'],
 ['A917', 'A024'],
 ['A172', 'A725'],
 ['A373', 'A647'],
 ['A489', 'A628'],
 ['A606', 'A604'],
 ['A769', 'A021'],
 ['A297', 'A613'],
 ['A823', 'A811'],
 ['A861', 'A625'],
 ['A939', 'A650'],
 ['A025', 'A837'],
 ['A120', 'A915'],
 ['A160', 'A910'],
 ['A195', 'A916'],
 ['A265', 'A664'],
 ['A287', 'A660'],
 ['A354', 'A241'],
 ['A199', 'A662'],
 ['A396', 'A626'],
 ['A595', 'A678'],
 ['B003', 'A896'],
 ['A001', None],
 ['A668', 'A020'],
 ['A678', 'A624'],
 ['A683', 'A865'],
 ['A919', 'A024'],
 ['A127', 'A623'],
 ['A269', 'A766'],
 ['A484', 'A702'],
 ['A528', 'A802'],
 ['A151', 'A766'],
 ['A180', 'A654'],
 ['A875', 'A642'],
 ['A953', 'A629'],
 ['A179', 'A654'],
 ['A351', 'A018'],
 ['A460', 'A646'],
 ['A873', 'A709'],
 ['A070', 'A723'],
 ['A132', 'A709'],
 ['A430', 'A675'],
 ['A600', 'A680'],
 ['A943', 'A018'],
 ['A026', 'A681'],
 ['A268', 'A765'],
 ['A611', 'A977'],
 ['A420', 'A704'],
 ['A994', 'A639'],
 ['A142', 'A713'],
 ['A716', 'A020'],
 ['A734', 'A021'],
 ['A746', 'A754'],
 ['A803', 'A802'],
 ['A017', 'A655'],
 ['A146', 'A713'],
 ['A356', 'A630'],
 ['A432', 'A667'],
 ['A466', 'A682'],
 ['A496', 'A628'],
 ['A759', 'A664'],
 ['A839', 'A607'],
 ['A064', 'A651'],
 ['A111', 'A620'],
 ['A155', 'A909'],
 ['A250', 'A676'],
 ['A274', 'A905'],
 ['A643', 'A020'],
 ['A954', 'A629'],
 ['A991', 'A639'],
 ['A004', 'A833'],
 ['A108', 'A614'],
 ['A289', 'A660'],
 ['A530', 'A667'],
 ['A538', 'A617'],
 ['A541', 'A617'],
 ['A613', 'A020'],
 ['A616', 'A025'],
 ['A902', 'A992'],
 ['A039', 'A657'],
 ['A181', 'A654'],
 ['A230', 'A698'],
 ['A426', 'A666'],
 ['A436', 'A689'],
 ['A520', 'A021'],
 ['A810', 'A629'],
 ['A339', 'A721'],
 ['A721', 'A020'],
 ['A990', 'A639'],
 ['A235', 'A634'],
 ['A253', 'A676'],
 ['A367', 'A616'],
 ['A439', 'A690'],
 ['A515', 'A683'],
 ['A870', 'A811'],
 ['A054', 'A685'],
 ['A280', 'A903'],
 ['A292', 'A714'],
 ['A697', 'A021'],
 ['A886', 'A728'],
 ['A934', 'A020'],
 ['A034', 'A728'],
 ['A217', 'A668'],
 ['A077', 'A717'],
 ['A232', 'A634'],
 ['A263', 'A664'],
 ['A069', 'A723'],
 ['A710', 'A020'],
 ['A891', 'A723'],
 ['A140', 'A712'],
 ['A291', 'A660'],
 ['A401', 'A672'],
 ['A437', 'A800'],
 ['A483', 'A702'],
 ['A768', 'A702'],
 ['A189', 'A916'],
 ['A739', 'A936'],
 ['A855', 'A848'],
 ['A336', 'A721'],
 ['A388', 'A800'],
 ['A591', 'A678'],
 ['A786', 'A674'],
 ['A909', 'A024'],
 ['A123', 'A915'],
 ['A225', 'A686'],
 ['A824', 'A811'],
 ['A399', 'A991'],
 ['A427', 'A666'],
 ['A446', 'A800'],
 ['A491', 'A628'],
 ['A033', 'A031'],
 ['A119', 'A915'],
 ['A240', 'A914'],
 ['A593', 'A596'],
 ['A634', 'A020'],
 ['A153', 'A911'],
 ['A165', 'A627'],
 ['A355', 'A630'],
 ['A657', 'A001'],
 ['A841', 'A603'],
 ['A036', 'A034'],
 ['A406', 'A798'],
 ['A632', 'A020'],
 ['A665', 'A020'],
 ['A868', 'A691'],
 ['A766', 'A717'],
 ['A874', 'A683'],
 ['A579', 'A700'],
 ['A614', 'A020'],
 ['A845', 'A968'],
 ['A086', 'A717'],
 ['A139', 'A712'],
 ['A311', 'A765'],
 ['A884', 'A833'],
 ['A137', 'A719'],
 ['A148', 'A710'],
 ['A177', 'A663'],
 ['A400', 'A639'],
 ['A537', 'A637'],
 ['A114', 'A665'],
 ['A144', 'A713'],
 ['A175', 'A663'],
 ['A258', 'A699'],
 ['A266', 'A664'],
 ['A366', 'A616'],
 ['A656', 'A020'],
 ['A930', 'A920'],
 ['A145', 'A802'],
 ['A241', 'A024'],
 ['A346', 'A632'],
 ['A419', 'A704'],
 ['A765', 'A717'],
 ['A850', 'A848'],
 ['A882', 'A899'],
 ['A915', 'A024'],
 ['A918', 'A024'],
 ['A978', 'A937'],
 ['A060', 'A658'],
 ['A778', 'A628'],
 ['A817', 'A690'],
 ['A980', 'A978'],
 ['A124', 'A915'],
 ['A462', 'A674'],
 ['A742', 'A754'],
 ['A779', 'A628'],
 ['A936', 'A020'],
 ['A974', 'A800'],
 ['A247', 'A705'],
 ['A476', 'A647'],
 ['A603', 'A657'],
 ['A787', 'A674'],
 ['A825', 'A811'],
 ['A319', 'A024'],
 ['A324', 'A652'],
 ['A888', 'A696'],
 ['A911', 'A024'],
 ['A141', 'A712'],
 ['A428', 'A666'],
 ['A429', 'A992'],
 ['A444', 'A798'],
 ['A457', 'A707'],
 ['A494', 'A628'],
 ['A714', 'A020'],
 ['A812', 'A811'],
 ['A840', 'A607'],
 ['A090', 'A912'],
 ['A110', 'A620'],
 ['A152', 'A911'],
 ['A170', 'A725'],
 ['A102', 'A648'],
 ['A267', 'A664'],
 ['A663', 'A020'],
 ['A738', 'A936'],
 ['A927', 'A920'],
 ['A941', 'A650'],
 ['A028', 'A681'],
 ['A323', 'A652'],
 ['A454', 'A697'],
 ['A832', 'A001'],
 ['A910', 'A024'],
 ['A947', 'A943'],
 ['A375', 'A647'],
 ['A410', 'A625'],
 ['A588', 'A751'],
 ['A644', 'A697'],
 ['A660', 'A020'],
 ['A883', 'A833'],
 ['A101', 'A648'],
 ['A159', 'A908'],
 ['A744', 'A754'],
 ['A781', 'A628'],
 ['A926', 'A919'],
 ['A049', 'A828'],
 ['A100', 'A695'],
 ['A205', 'A706'],
 ['A293', 'A714'],
 ['A631', 'A020'],
 ['A050', 'A828'],
 ['A531', 'A637'],
 ['A552', 'A641'],
 ['A698', 'A020'],
 ['A907', 'A024'],
 ['A912', 'A024'],
 ['A024', 'A837'],
 ['A572', 'A802'],
 ['A890', 'A690'],
 ['A965', 'A935'],
 ['A924', 'A918'],
 ['A979', 'A978'],
 ['A173', 'A725'],
 ['A187', 'A916'],
 ['A321', 'A901'],
 ['A391', 'A625'],
 ['A505', 'A691'],
 ['A857', 'A631'],
 ['A097', 'A687'],
 ['A534', 'A637'],
 ['A811', 'A021'],
 ['A118', 'A629'],
 ['A282', 'A904'],
 ['A397', 'A626'],
 ['A272', 'A903'],
 ['A422', 'A704'],
 ['A637', 'A021'],
 ['A646', 'A865'],
 ['A093', 'A912'],
 ['A358', 'A638'],
 ['A431', 'A675'],
 ['A487', 'A943'],
 ['A630', 'A021'],
 ['A758', 'A664'],
 ['A075', 'A756'],
 ['A117', 'A765'],
 ['A762', 'A828'],
 ['A893', 'A488'],
 ['A402', 'A672'],
 ['A756', 'A651'],
 ['A838', 'A613'],
 ['A925', 'A919'],
 ['A171', 'A725'],
 ['A210', 'A669'],
 ['A226', 'A686'],
 ['A243', 'A914'],
 ['A386', 'A625'],
 ['A775', 'A908'],
 ['A056', 'A685'],
 ['A887', 'A049'],
 ['A081', 'A717'],
 ['A982', 'A937'],
 ['A989', 'A986'],
 ['A190', 'A906'],
 ['A284', 'A908'],
 ['A434', 'A667'],
 ['A650', 'A728'],
 ['A892', 'A723'],
 ['A898', 'A865'],
 ['A298', 'A613'],
 ['A378', 'A798'],
 ['A818', 'A802'],
 ['A322', 'A652'],
 ['A589', 'A751'],
 ['A942', 'A919'],
 ['A983', 'A982'],
 ['A473', 'A802'],
 ['A833', 'A001'],
 ['A543', 'A617'],
 ['A150', 'A710'],
 ['A403', 'A625'],
 ['A456', 'A707'],
 ['A519', 'A865'],
 ['A360', 'A638'],
 ['A620', 'A020'],
 ['A712', 'A020'],
 ['A717', 'A025'],
 ['A805', 'A319'],
 ['A096', 'A687'],
 ['A305', 'A656'],
 ['A533', 'A637'],
 ['A755', 'A651'],
 ['A194', 'A917'],
 ['A557', 'A642'],
 ['A680', 'A624'],
 ['A908', 'A024'],
 ['A459', 'A646'],
 ['A087', 'A717'],
 ['A228', 'A698'],
 ['A623', 'A020'],
 ['A662', 'A020'],
 ['A666', 'A865'],
 ['A676', 'A020'],
 ['A270', 'A907'],
 ['A461', 'A646'],
 ['A066', 'A723'],
 ['A443', 'A798'],
 ['A509', 'A690'],
 ['A568', 'A798'],
 ['A831', 'A488'],
 ['A192', 'A917'],
 ['A296', 'A714'],
 ['A542', 'A617'],
 ['A590', 'A678'],
 ['A664', 'A020'],
 ['A955', 'A935'],
 ['A007', 'A696'],
 ['A098', 'A695'],
 ['A130', 'A623'],
 ['A245', 'A705'],
 ['A278', 'A906'],
 ['A674', 'A865'],
 ['A688', 'A021'],
 ['A935', 'A020'],
 ['A981', 'A978'],
 ['A409', 'A800'],
 ['A452', 'A697'],
 ['A867', 'A643'],
 ['A045', 'A624'],
 ['A203', 'A706'],
 ['A312', 'A629'],
 ['A327', 'A633'],
 ['A901', 'A024'],
 ['A946', 'A943'],
 ['A425', 'A666'],
 ['A639', 'A025'],
 ['A760', 'A624'],
 ['A229', 'A698'],
 ['A363', 'A616'],
 ['A682', 'A021'],
 ['A326', 'A652'],
 ['A713', 'A020'],
 ['A830', 'A488'],
 ['A853', 'A848'],
 ['A094', 'A912'],
 ['A337', 'A721'],
 ['A615', 'A903'],
 ['A808', 'A651'],
 ['A020', 'A837'],
 ['A183', 'A629'],
 ['A580', 'A700'],
 ['A648', 'A020'],
 ['A948', 'A018'],
 ['A200', 'A662'],
 ['A334', 'A631'],
 ['A471', 'A688'],
 ['A516', 'A683'],
 ['A627', 'A020'],
 ['A995', 'A639'],
 ['A517', 'A683'],
 ['A231', 'A634'],
 ['A629', 'A762'],
 ['A156', 'A909'],
 ['A234', 'A634'],
 ['A383', 'A798'],
 ['A418', 'A704'],
 ['A485', 'A702'],
 ['A695', 'A020'],
 ['A876', 'A647'],
 ['A972', 'A897'],
 ['A091', 'A912'],
 ['A236', 'A634'],
 ['A455', 'A707'],
 ['A559', 'A642'],
 ['A642', 'A021'],
 ['A692', 'A718'],
 ['A952', 'A629'],
 ['A022', 'A681'],
 ['A206', 'A706'],
 ['A390', 'A798'],
 ['A161', 'A627'],
 ['A310', 'A716'],
 ['A653', 'A020'],
 ['A286', 'A906'],
 ['A315', 'A901'],
 ['A754', 'A021'],
 ['B001', 'A896'],
 ['A061', 'A658'],
 ['A129', 'A623'],
 ['A252', 'A676'],
 ['A318', 'A901'],
 ['A379', 'A798'],
 ['A607', 'A657'],
 ['A377', 'A802'],
 ['A163', 'A627'],
 ['A450', 'A697'],
 ['A789', 'A685'],
 ['A214', 'A668'],
 ['A294', 'A714'],
 ['A677', 'A001'],
 ['A767', 'A910'],
 ['A894', 'A632'],
 ['A921', 'A918'],
 ['A923', 'A918'],
 ['A822', 'A811'],
 ['A063', 'A651'],
 ['A138', 'A719'],
 ['A343', 'A643'],
 ['A582', 'A692'],
 ['A652', 'A020'],
 ['A763', 'A617'],
 ['A029', 'A828'],
 ['A051', 'A001'],
 ['A207', 'A706'],
 ['A820', 'A811'],
 ['A863', 'A642'],
 ['A341', 'A643'],
 ['A654', 'A020'],
 ['A864', 'A790'],
 ['A083', 'A717'],
 ['A246', 'A705'],
 ['A604', 'A657'],
 ['A605', 'A604'],
 ['A628', 'A025'],
 ['A809', 'A723'],
 ['A842', 'A603'],
 ['A973', 'A897'],
 ['A220', 'A635'],
 ['A380', 'A647'],
 ['A802', 'A865'],
 ['A966', 'A800'],
 ['A013', 'A650'],
 ['A352', 'A241'],
 ['A480', 'A865'],
 ['A502', 'A722'],
 ['A527', 'A802'],
 ['A700', 'A624'],
 ['A702', 'A021'],
 ['A859', 'A673'],
 ['A106', 'A614'],
 ['A306', 'A656'],
 ['A506', 'A798'],
 ['A691', 'A722'],
 ['A862', 'A667'],
 ['A871', 'A686'],
 ['A325', 'A652'],
 ['A567', 'A798'],
 ['A920', 'A024'],
 ['A043', 'A031'],
 ['A411', 'A800'],
 ['A577', 'A700'],
 ['A724', 'A021'],
 ['A785', 'A865'],
 ['A015', 'A655'],
 ['A277', 'A906'],
 ['A384', 'A647'],
 ['A539', 'A617'],
 ['A866', 'A968'],
 ['A303', 'A656'],
 ['A773', 'A704'],
 ['A826', 'A811'],
 ['A300', 'A613'],
 ['A574', 'A724'],
 ['A211', 'A669'],
 ['A262', 'A664'],
 ['A782', 'A628'],
 ['A115', 'A665'],
 ['A201', 'A662'],
 ['A438', 'A690'],
 ['A774', 'A710'],
 ['A992', 'A639'],
 ['A285', 'A907'],
 ['A722', 'A865'],
 ['A143', 'A713'],
 ['A314', 'A901'],
 ['A587', 'A718'],
 ['A635', 'A020'],
 ['A984', 'A982'],
 ['A344', 'A632'],
 ['A745', 'A754'],
 ['A819', 'A828'],
 ['A860', 'A647'],
 ['A937', 'A020'],
 ['A062', 'A658'],
 ['A122', 'A915'],
 ['A197', 'A906'],
 ['A986', 'A937'],
 ['A112', 'A665'],
 ['A827', 'A811'],
 ['A027', 'A681'],
 ['A196', 'A917'],
 ['A204', 'A706'],
 ['A273', 'A905'],
 ['A295', 'A714'],
 ['A828', 'A001'],
 ['A914', 'A024'],
 ['B004', 'A896'],
 ['A218', 'A668'],
 ['A256', 'A699'],
 ['A308', 'A716'],
 ['A385', 'A992'],
 ['A858', 'A673'],
 ['A238', 'A914'],
 ['A335', 'A721'],
 ['A368', 'A616'],
 ['A389', 'A625'],
 ['A392', 'A800'],
 ['A447', 'A800'],
 ['A633', 'A020'],
 ['A814', 'A627'],
 ['A191', 'A917'],
 ['A222', 'A635'],
 ['A357', 'A638'],
 ['A037', 'A034'],
 ['A065', 'A723'],
 ['A157', 'A910'],
 ['A553', 'A990'],
 ['A624', 'A001'],
 ['A103', 'A648'],
 ['A895', 'A632'],
 ['A521', 'A990'],
 ['A558', 'A798'],
 ['A562', 'A642'],
 ['A584', 'A692'],
 ['A675', 'A865'],
 ['A743', 'A754'],
 ['A764', 'A755'],
 ['A829', 'A488'],
 ['A340', 'A643'],
 ['A376', 'A647'],
 ['A482', 'A702'],
 ['A949', 'A677'],
 ['A331', 'A631'],
 ['A345', 'A632'],
 ['A467', 'A682'],
 ['A880', 'A638'],
 ['A932', 'A837'],
 ['A255', 'A720'],
 ['A348', 'A765'],
 ['A571', 'A802'],
 ['A031', 'A728'],
 ['A464', 'A682'],
 ['A854', 'A848'],
 ['A475', 'A647'],
 ['A565', 'A802'],
 ['A798', 'A865'],
 ['A977', 'A001'],
 ['A076', 'A756'],
 ['A224', 'A635'],
 ['A555', 'A673'],
 ['A592', 'A678'],
 ['A843', 'A968'],
 ['A251', 'A676'],
 ['A288', 'A660'],
 ['A523', 'A642'],
 ['A545', 'A617'],
 ['A959', 'A714'],
 ['A486', 'A702'],
 ['A497', 'A691'],
 ['A733', 'A021'],
 ['A131', 'A709'],
 ['A149', 'A710'],
 ['A374', 'A991'],
 ['A458', 'A646'],
 ['A492', 'A628'],
 ['A513', 'A683'],
 ['A896', 'A021'],
 ['A655', 'A728'],
 ['A449', 'A697'],
 ['A477', 'A616'],
 ['A560', 'A642'],
 ['A770', 'A865'],
 ['A879', 'A800'],
 ['A933', 'A020'],
 ['A221', 'A635'],
 ['A283', 'A903'],
 ['A309', 'A716'],
 ['A381', 'A802'],
 ['A638', 'A021'],
 ['A673', 'A865'],
 ['A074', 'A755'],
 ['A089', 'A912'],
 ['A162', 'A627'],
 ['A178', 'A663'],
 ['A257', 'A699'],
 ['A585', 'A692'],
 ['A316', 'A901'],
 ['A441', 'A667'],
 ['A610', 'A977'],
 ['A669', 'A020'],
 ['A186', 'A916'],
 ['A481', 'A702'],
 ['A169', 'A653'],
 ['A299', 'A613'],
 ['A342', 'A643'],
 ['A353', 'A639'],
 ['A493', 'A628'],
 ['A511', 'A689'],
 ['A586', 'A718'],
 ['A651', 'A020'],
 ['A976', 'A798'],
 ['A227', 'A686'],
 ['A248', 'A705'],
 ['A510', 'A689'],
 ['A687', 'A020'],
 ['A707', 'A021'],
 ['A804', 'A717'],
 ['A837', 'A001'],
 ['A848', 'A021'],
 ['A899', 'A624'],
 ['A055', 'A685'],
 ['A290', 'A660'],
 ['A423', 'A704'],
 ['A672', 'A865'],
 ['A719', 'A020'],
 ['A922', 'A918'],
 ['A958', 'A933'],
 ['A996', 'A639'],
 ['A740', 'A021'],
 ['A369', 'A616'],
 ['A507', 'A802'],
 ['A532', 'A637'],
 ['A929', 'A920'],
 ['A463', 'A674'],
 ['A699', 'A020'],
 ['A849', 'A848'],
 ['A504', 'A691'],
 ['A800', 'A865'],
 ['A126', 'A915'],
 ['A465', 'A682'],
 ['A472', 'A688'],
 ['A776', 'A620'],
 ['A851', 'A848'],
 ['A951', 'A629'],
 ['A237', 'A766'],
 ['A338', 'A721'],
 ['A554', 'A673'],
 ['A904', 'A024'],
 ['A508', 'A690'],
 ['A709', 'A020'],
 ['A791', 'A917'],
 ['A970', 'A936'],
 ['A084', 'A765'],
 ['A105', 'A614'],
 ['A158', 'A910'],
 ['A469', 'A682'],
 ['A540', 'A617'],
 ['A944', 'A943'],
 ['A264', 'A664'],
 ['A424', 'A704'],
 ['A608', 'A828'],
 ['A330', 'A633'],
 ['A599', 'A680'],
 ['A967', 'A001'],
 ['A550', 'A641'],
 ['A718', 'A624'],
 ['A271', 'A904'],
 ['A681', 'A020'],
 ['A950', 'A001'],
 ['A048', 'A624'],
 ['A500', 'A689'],
 ['A799', 'A798'],
 ['A058', 'A658'],
 ['A071', 'A755'],
 ['A135', 'A719'],
 ['A254', 'A720'],
 ['A581', 'A718'],
 ['A667', 'A021'],
 ['A928', 'A837'],
 ['A382', 'A802'],
 ['A720', 'A020'],
 ['A987', 'A986'],
 ['A435', 'A798'],
 ['A889', 'A001'],
 ['A985', 'A982'],
 ['A073', 'A755'],
 ['A104', 'A648'],
 ['A806', 'A319'],
 ['A931', 'A639'],
 ['A938', 'A658'],
 ['A259', 'A699'],
 ['A442', 'A667'],
 ['A518', 'A683'],
 ['A906', 'A024'],
 ['A304', 'A656'],
 ['A696', 'A728'],
 ['A393', 'A800'],
 ['A757', 'A798'],
 ['A182', 'A654'],
 ['A242', 'A914'],
 ['A468', 'A682'],
 ['A564', 'A802'],
 ['A244', 'A914'],
 ['A529', 'A802'],
 ['A569', 'A642'],
 ['A971', 'A629'],
 ['A113', 'A665'],
 ['A617', 'A021'],
 ['A053', 'A020'],
 ['A333', 'A631'],
 ['A133', 'A709'],
 ['A212', 'A669'],
 ['A349', 'A018'],
 ['A470', 'A688'],
 ['A728', 'A001'],
 ['A741', 'A754'],
 ['A761', 'A638'],
 ['A865', 'A677'],
 ['A968', 'A967'],
 ['A551', 'A641'],
 ['A685', 'A024'],
 ['A686', 'A020'],
 ['A404', 'A625'],
 ['A433', 'A667'],
 ['A556', 'A642'],
 ['A597', 'A678'],
 ['A018', 'A677'],
 ['A215', 'A668'],
 ['A332', 'A631'],
 ['A576', 'A724'],
 ['A913', 'A992'],
 ['A940', 'A650'],
 ['A474', 'A647'],
 ['A885', 'A901'],
 ['A969', 'A936'],
 ['A134', 'A709'],
 ['A164', 'A627'],
 ['A877', 'A625'],
 ['A008', 'A696'],
 ['A184', 'A916'],
 ['A370', 'A616'],
 ['A813', 'A689'],
 ['A957', 'A933'],
 ['A993', 'A625'],
 ['A598', 'A680'],
 ['A689', 'A722'],
 ['A852', 'A848'],
 ['A525', 'A865'],
 ['A535', 'A637'],
 ['A563', 'A802'],
 ['A583', 'A692'],
 ['A905', 'A024'],
 ['A166', 'A653'],
 ['A421', 'A704'],
 ['A945', 'A943'],
 ['A328', 'A633'],
 ['A407', 'A798'],
 ['A451', 'A697'],
 ['A594', 'A596'],
 ['A596', 'A678']]

# %%
df_graf = pd.DataFrame(graf)
df_

# %%
graf = [[x['id'], x['parent']] for i,x in df.iterrows()]
# graf = [{x['id']: x['parent']} for i,x in df.iterrows()]
graf
# Out:
# [['A001', None],
#  ['A002', 'A001'],
#  ['A003', 'A002'],
#  ['A004', 'A001'],
#  ['A005', 'A003']]

# %%
## test cell
fasit = []
def fill_table(graf, fasit):
    if not fasit:
        for i,g in enumerate(graf):
            if g[1]==None:
                fasit.append([g[0]])
                graf.pop(i)
    for j,f in enumerate(fasit):
        if not graf:
            break
        for i,g in enumerate(graf):
            if f[-1] == g[1]:
                fasit.append(f + [g[0]])
                graf.pop(i)
    return fasit
fas = fill_table(graf, fasit)

# pd.DataFrame(fas).interpolate('pad')

# %%
fas = fill_table(graf, fasit)

# %%
pd.DataFrame(fas)#.interpolate('pad')
# Out:
#         0     1     2     3     4     5
# 0    A001  None  None  None  None  None
# 1    A001  A657  None  None  None  None
# 2    A001  A832  None  None  None  None
# 3    A001  A833  None  None  None  None
# 4    A001  A677  None  None  None  None
# ..    ...   ...   ...   ...   ...   ...
# 856  A001  A837  A020  A665  A114  None
# 857  A001  A837  A020  A665  A115  None
# 858  A001  A837  A020  A665  A112  None
# 859  A001  A837  A020  A712  A140  None
# 860  A001  A837  A020  A712  A141  None
#
# [861 rows x 6 columns]

# %%
# fasit = []
# def fill_table(graf, fasit):
#     if not fasit:
#         for i,g in enumerate(graf):
#             if g[1]!=g[1]:
#                 fasit.append([g[0]])
#                 graf.pop(i)
#     for j,f in enumerate(fasit):
#         if not graf:
#             break
#         for i,g in enumerate(graf):
#             if f[-1] == g[1]:
#                 fasit.append(f + [g[0]])
#                 graf.pop(i)
#     return fasit
# fas = fill_table(graf, fasit)
# pd.DataFrame(fas).interpolate('pad')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# def get_children(parents, df_out,i=0):
#     temp = pd.DataFrame()
#     for _,parent in enumerate(parents):
#         df_child = df[df.parent == parent]
#         df_parent = df[df.id == parent]
#         if df_child.shape[0] == 0:
#             pass
            
#         else:
#             temp['id'] = df_child.loc[:, ('id')]
#             temp['nivå_'+str(i)] = df_child.loc[:, ('parent')]
#             temp['nivå_'+str(i+1)] = df_child.loc[:, ('id')]
            
#             if df_out.shape[0]!=0:
#                 df_merger = temp.merge(df_out, on=['nivå_'+str(i)])
#                 columns_to_drop = [colum for colum   in df_merger.columns if 'x' in colum or 'y' in colum]
#                 df_merger.drop(columns=columns_to_drop, inplace=True)
#                 df_out = pd.concat([df_out, df_merger])
                
#             else:
#                 df_out = pd.concat([df_out, temp])                    
            
#             grandchild = get_children(parents=df_out['nivå_'+str(i)], i = i+1, df_out=df_out)
#             df_out = pd.concat([df_out, grandchild])

    
#     df_out.drop_duplicates(inplace=True)
#     return  df_out
        
# parent = [1.0]
# df_out = pd.DataFrame()
# test = get_children(parents=parent, df_out=df_out)
# test.head()
